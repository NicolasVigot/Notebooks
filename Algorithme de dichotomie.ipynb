# %% [markdown]
# # L'algorithme de dichtomie
#
# On considère la fonction $f$ définie sur $\mathbb{R}$ par $$f(x)=-x^3+24x^2-117x-200$$
# Une étude graphique montre que cette fonction admet une racine entre 15 et 20 (mais dont on ne sait pas trouver une valeur exacte). L'algorithme de dichotomie vise à donner un encadrement aussi précis que voulu de cette racine.

# %%
def f(x):
    return -x**3+24*x**2-117*x-200

# %%
def dichotomie(a,b,précision):
    if f(a)*f(b)>0:
        print("Pas de racine dans l'intervalle considéré")
        return Null
    etape = 1
    while abs(b-a)>précision :
        c = (a+b)/2
        if f(a)*f(c)<0:
            b=c
        else :
            a=c
        print(f"Etape {etape} : {a} < alpha < {b}")
        etape +=1
    return a,b

# %%
dichotomie(15,20,0.01)
# Out:
# Etape 1 : 15 < alpha < 17.5
# Etape 2 : 15 < alpha < 16.25
# Etape 3 : 15.625 < alpha < 16.25
# Etape 4 : 15.625 < alpha < 15.9375
# Etape 5 : 15.78125 < alpha < 15.9375
# Etape 6 : 15.78125 < alpha < 15.859375
# Etape 7 : 15.78125 < alpha < 15.8203125
# Etape 8 : 15.78125 < alpha < 15.80078125
# Etape 9 : 15.78125 < alpha < 15.791015625
# (15.78125, 15.791015625)
