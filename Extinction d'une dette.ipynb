# %% [markdown]
# # Un problème d'Euler : extinction d'une dette

# %%
Capital = 400000
Intérêt = 0.05
Mensualité = 25000
Année = 0

while Capital>0:
    message = f"Année : {Année:<10}    Capital restant : {Capital:>.2f}"
    print(message)
    Capital += Capital*Intérêt-Mensualité
    Année += 1
# Out:
# Année : 0             Capital restant : 400000.00
# Année : 1             Capital restant : 395000.00
# Année : 2             Capital restant : 389750.00
# Année : 3             Capital restant : 384237.50
# Année : 4             Capital restant : 378449.38
# Année : 5             Capital restant : 372371.84
# Année : 6             Capital restant : 365990.44
# Année : 7             Capital restant : 359289.96
# Année : 8             Capital restant : 352254.46
# Année : 9             Capital restant : 344867.18
# Année : 10            Capital restant : 337110.54
# Année : 11            Capital restant : 328966.06
# Année : 12            Capital restant : 320414.37
# Année : 13            Capital restant : 311435.09
# Année : 14            Capital restant : 302006.84
# Année : 15            Capital restant : 292107.18
# Année : 16            Capital restant : 281712.54
# Année : 17            Capital restant : 270798.17
# Année : 18            Capital restant : 259338.08
# ...
