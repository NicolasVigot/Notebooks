# %%
from sympy import Matrix

# %% [markdown]
# # Exercice 57

# %%
A=Matrix([[1,-2,-6],[-3,2,9],[2,0,-3]])

# %%
A*A
# Out:
# Matrix([
# [-5, -6, -6],
# [ 9, 10,  9],
# [-4, -4, -3]])

# %%
A**2
# Out:
# Matrix([
# [-5, -6, -6],
# [ 9, 10,  9],
# [-4, -4, -3]])

# %%
A**3
# Out:
# Matrix([
# [ 1, -2, -6],
# [-3,  2,  9],
# [ 2,  0, -3]])

# %%
A**7
# Out:
# Matrix([
# [ 1, -2, -6],
# [-3,  2,  9],
# [ 2,  0, -3]])

# %% [markdown]
# # Exercice 62

# %%
A=Matrix([[1,0],[-1,1]])

# %%
A
# Out:
# Matrix([
# [ 1, 0],
# [-1, 1]])

# %%
A.inv()
# Out:
# Matrix([
# [1, 0],
# [1, 1]])

# %%
B=Matrix([[1,-1],[0,1]])

# %%
B
# Out:
# Matrix([
# [1, -1],
# [0,  1]])

# %%
B.inv()
# Out:
# Matrix([
# [1, 1],
# [0, 1]])
