# %%
from math import sqrt

# %%
def briggs(precision):
    n = 0
    u, v, a, b = 1, 10, 0, 1
    while abs(b-a) > precision:
        if sqrt(u*v) < 9:
            u, a = ..., ...
        else:
            v, b = ..., ... 
    return a,b

# %%
briggs(0.0000000001)
